# %%
import pyodbc
import numpy as np 
import pandas as pd

# %%
connect = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
                         'server=DESKTOP-C8VL8BV;'
                         'database=Customer;'
                         'trusted_connection=yes;'

)

# %%
connect

# %% [markdown]
# # 1. Retrieve all records from the Customer table.

# %%
df1 = pd.read_sql("SELECT * FROM Customer", connect)
df1.head()
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\2659885592.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql("SELECT * FROM Customer", connect)
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# ...

# %%
df2 = pd.read_sql("select * from Invoice", connect)
df2
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\4092482425.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2 = pd.read_sql("select * from Invoice", connect)
#      InvoiceId  CustomerId InvoiceDate  \
# 0            1           2  2009-01-01
# 1            2           4  2009-01-02
# 2            3           8  2009-01-03
# 3            4          14  2009-01-06
# 4            5          23  2009-01-11
# ..         ...         ...         ...
# 407        408          25  2013-12-05
# 408        409          29  2013-12-06
# 409        410          35  2013-12-09
# 410        411          44  2013-12-14
# 411        412          58  2013-12-22
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart         None
# ...

# %%
df3= pd.read_sql("select * from InvoiceLine", connect)
df3
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\1360340032.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df3= pd.read_sql("select * from InvoiceLine", connect)
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0                 1          1        2       0.99         1
# 1                 2          1        4       0.99         1
# 2                 3          2        6       0.99         1
# 3                 4          2        8       0.99         1
# 4                 5          2       10       0.99         1
# ...             ...        ...      ...        ...       ...
# 2235           2236        411     3136       0.99         1
# 2236           2237        411     3145       0.99         1
# 2237           2238        411     3154       0.99         1
# ...

# %% [markdown]
# # --2. Retrieve all invoices for a specific customer.

# %%
pd.read_sql("select *from Invoice where CustomerID = 20", connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\1867641386.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select *from Invoice where CustomerID = 20", connect)
#    InvoiceId  CustomerId InvoiceDate        BillingAddress    BillingCity  \
# 0        113          20  2010-05-12  541 Del Medio Avenue  Mountain View
# 1        124          20  2010-06-22  541 Del Medio Avenue  Mountain View
# 2        179          20  2011-02-20  541 Del Medio Avenue  Mountain View
# 3        308          20  2012-09-26  541 Del Medio Avenue  Mountain View
# 4        331          20  2012-12-29  541 Del Medio Avenue  Mountain View
# 5        353          20  2013-04-02  541 Del Medio Avenue  Mountain View
# 6        405          20  2013-11-21  541 Del Medio Avenue  Mountain View
#
# ...

# %% [markdown]
# # --3. List all invoice lines along with their corresponding invoice and customer information.

# %%
pd.read_sql("select Invoice.InvoiceId ,Invoice.Total ,Invoice.InvoiceDate,Customer.CustomerId,Customer.FirstName,Customer.LastName from Customer join Invoice on Invoice.CustomerId = Customer.CustomerId",
connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\291604484.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select Invoice.InvoiceId ,Invoice.Total ,Invoice.InvoiceDate,Customer.CustomerId,Customer.FirstName,Customer.LastName from Customer join Invoice on Invoice.CustomerId = Customer.CustomerId",
#      InvoiceId  Total InvoiceDate  CustomerId FirstName    LastName
# 0            1   1.98  2009-01-01           2    Leonie      Köhler
# 1            2   3.96  2009-01-02           4     Bjørn      Hansen
# 2            3   5.94  2009-01-03           8      Daan     Peeters
# 3            4   8.91  2009-01-06          14      Mark     Philips
# 4            5  13.86  2009-01-11          23      John      Gordon
# ..         ...    ...         ...         ...       ...         ...
# ...

# %% [markdown]
# # --4. Calculate total invoice amount per customer.

# %%
pd.read_sql("select Customer.CustomerId,Customer.FirstName,Customer.LastName , sum(Invoice.Total) as total_invoice from Customer join Invoice on  Customer.CustomerId = Invoice.CustomerId group by Customer.CustomerId,Customer.FirstName,Customer.LastName",
connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\2284463118.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select Customer.CustomerId,Customer.FirstName,Customer.LastName , sum(Invoice.Total) as total_invoice from Customer join Invoice on  Customer.CustomerId = Invoice.CustomerId group by Customer.CustomerId,Customer.FirstName,Customer.LastName",
#     CustomerId  FirstName      LastName  total_invoice
# 0            1       Luís     Gonçalves      39.620000
# 1            2     Leonie        Köhler      37.620000
# 2            3   François      Tremblay      39.620000
# 3            4      Bjørn        Hansen      39.620000
# 4            5  František   Wichterlová      40.620001
# 5            6     Helena          Holý      49.620001
# 6            7     Astrid        Gruber      42.620001
# ...

# %% [markdown]
# # --5. Retrieve the top 5 customers by total spending.

# %%
pd.read_sql("select top(5) Customer.CustomerId,Customer.FirstName,Customer.LastName , sum(Invoice.Total) as total_invoice from Customer join Invoice on  Customer.CustomerId = Invoice.CustomerId group by Customer.CustomerId,Customer.FirstName,Customer.LastName order by total_invoice desc",
connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\2069238392.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select top(5) Customer.CustomerId,Customer.FirstName,Customer.LastName , sum(Invoice.Total) as total_invoice from Customer join Invoice on  Customer.CustomerId = Invoice.CustomerId group by Customer.CustomerId,Customer.FirstName,Customer.LastName order by total_invoice desc",
#    CustomerId FirstName    LastName  total_invoice
# 0           6    Helena        Holý      49.620001
# 1          26   Richard  Cunningham      47.620001
# 2          57      Luis       Rojas      46.620000
# 3          45  Ladislav      Kovács      45.620001
# 4          46      Hugh    O'Reilly      45.620001

# %% [markdown]
# # --6. Count the number of invoices per customer.

# %%
pd.read_sql("select CustomerId,count(InvoiceID) as invoices_number from Invoice group by CustomerId order by invoices_number desc",
connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\2546033698.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select CustomerId,count(InvoiceID) as invoices_number from Invoice group by CustomerId order by invoices_number desc",
#     CustomerId  invoices_number
# 0            1                7
# 1            2                7
# 2            3                7
# 3            4                7
# 4            5                7
# 5            6                7
# 6            7                7
# 7            8                7
# 8            9                7
# 9           10                7
# 10          11                7
# 11          12                7
# 12          13                7
# 13          14                7
# 14          15                7
# 15          16                7
# ...

# %% [markdown]
# # --7. Calculate total quantity of tracks sold per invoice.

# %%
pd.read_sql("select InvoiceID,TrackId ,sum(Quantity) as total_quantity from InvoiceLine group by  InvoiceID , TrackId",
connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\678994190.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select InvoiceID,TrackId ,sum(Quantity) as total_quantity from InvoiceLine group by  InvoiceID , TrackId",
#       InvoiceID  TrackId  total_quantity
# 0           108        1               1
# 1             1        2               1
# 2           214        2               1
# 3           319        3               1
# 4             1        4               1
# ...         ...      ...             ...
# 2235        319     3494               1
# 2236        108     3496               1
# 2237        214     3499               1
# 2238        108     3500               1
# 2239        319     3500               1
#
# [2240 rows x 3 columns]

# %% [markdown]
# # --8. Retrieve all invoices where the total amount exceeds $50.

# %%
pd.read_sql("select * from Invoice where Total > 50", connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\2022676433.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from Invoice where Total > 50", connect)
# Empty DataFrame
# Columns: [InvoiceId, CustomerId, InvoiceDate, BillingAddress, BillingCity, BillingState, BillingCountry, BillingPostalCode, Total]
# Index: []

# %% [markdown]
# # --9. Identify the customer who purchased the most tracks overall.

# %%
pd.read_sql("select Customer.CustomerId , sum(InvoiceLine.Quantity) as total_quantity from Customer join Invoice on Customer.CustomerId = Invoice.CustomerId join InvoiceLine on Invoice.Invoiceid = InvoiceLine.Invoiceid group by Customer.CustomerId order by sum(Invoice.Total) desc", connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\215829699.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select Customer.CustomerId , sum(InvoiceLine.Quantity) as total_quantity from Customer join Invoice on Customer.CustomerId = Invoice.CustomerId join InvoiceLine on Invoice.Invoiceid = InvoiceLine.Invoiceid group by Customer.CustomerId order by sum(Invoice.Total) desc", connect)
#     CustomerId  total_quantity
# 0            6              38
# 1           26              38
# 2           46              38
# 3           45              38
# 4           57              38
# 5            7              38
# 6           25              38
# 7           37              38
# 8           24              38
# 9            5              38
# 10          43              38
# 11          28              38
# ...

# %% [markdown]
# # --10. List all invoices along with the number of items in each invoice.

# %%
pd.read_sql("SELECT Invoice.InvoiceID,COUNT(InvoiceLine.InvoicelineID) AS number_of_items FROM invoice JOIN InvoiceLine on Invoice.InvoiceID = InvoiceLine.InvoiceID group by Invoice.InvoiceID", connect)
# Out:
# C:\Users\LOQ\AppData\Local\Temp\ipykernel_15448\2324673732.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT Invoice.InvoiceID,COUNT(InvoiceLine.InvoicelineID) AS number_of_items FROM invoice JOIN InvoiceLine on Invoice.InvoiceID = InvoiceLine.InvoiceID group by Invoice.InvoiceID", connect)
#      InvoiceID  number_of_items
# 0          261                4
# 1           23                4
# 2          238                2
# 3          355               14
# 4           46                9
# ..         ...              ...
# 407        151                9
# 408        194               14
# 409        200                9
# 410        100                4
# 411        343                2
#
# [412 rows x 2 columns]

# %% [markdown]
# # merge tables

# %%
merged_df = df1.merge(df2, on='CustomerId', how='inner') \
               .merge(df3, on='InvoiceId', how='inner')
merged_df.head()
# Out:
#    CustomerId FirstName   LastName  \
# 0           1      Luís  Gonçalves
# 1           1      Luís  Gonçalves
# 2           1      Luís  Gonçalves
# 3           1      Luís  Gonçalves
# 4           1      Luís  Gonçalves
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 3  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 4  Embraer - Empresa Brasileira de Aeronáutica S.A.
#
#                            Address                 City State Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 1  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 2  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 3  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
# 4  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP  Brazil
#
# ...

# %%
merged_df.to_excel("merged_output.xlsx", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LOQ'

# %%
merged_df.info()
merged_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerId         2240 non-null   int64
#  1   FirstName          2240 non-null   object
#  2   LastName           2240 non-null   object
#  3   Company            380 non-null    object
#  4   Address            2240 non-null   object
#  5   City               2240 non-null   object
#  6   State              1140 non-null   object
#  7   Country            2240 non-null   object
#  8   PostalCode         2088 non-null   object
#  9   Phone              2202 non-null   object
#  10  Fax                456 non-null    object
#  11  Email              2240 non-null   object
#  12  SupportRepId       2240 non-null   int64
#  13  InvoiceId          2240 non-null   int64
#  14  InvoiceDate        2240 non-null   datetime64[ns]
#  15  BillingAddress     2240 non-null   object
# ...

# %%
merged_df.isna().sum()
# Out:
# CustomerId              0
# FirstName               0
# LastName                0
# Company              1860
# Address                 0
# City                    0
# State                1100
# Country                 0
# PostalCode            152
# Phone                  38
# Fax                  1784
# Email                   0
# SupportRepId            0
# InvoiceId               0
# InvoiceDate             0
# BillingAddress          0
# BillingCity             0
# BillingState         1100
# BillingCountry          0
# BillingPostalCode     152
# Total                   0
# InvoiceLineId           0
# TrackId                 0
# UnitPrice               0
# Quantity                0
# dtype: int64

# %%
connect.close()
